# %% [markdown]
# # 1. Primer intento

# %% [markdown]
# ## Números aleatorios

# %% [markdown]
# Generar números aleatorios en python es fácil:

# %%
import random

N = 10
X = []

for i in range(N):
    X.append(random.randrange(1, N) )

print(X)
# Out:
# [5, 7, 6, 3, 8, 4, 1, 6, 1, 7]

# %% [markdown]
# Pero podemos hacerlo mejor.
# Quería poder elegir la media y la variancia.
#
# Para ello he encontrado algunos links que debo ojear:
#
# - https://stackoverflow.com/questions/49855569/how-to-generate-random-numbers-to-satisfy-a-specific-mean-and-median-in-python
# - https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.normal.html
# - https://docs.python.org/3/library/statistics.html
#
#
# Por ahora he usado la forma usada [aqui](https://stackoverflow.com/questions/8815706/random-number-with-specific-variance-in-python)

# %%
import math
from random import gauss

N = 100
media = 0
varianza = 10
t = 20

# %%
ye = []
for j in range(t):
    X = [gauss(media, math.sqrt(varianza)) for i in range(N)]

    Y = 0
    for i in range(N):
        Y = Y + X[i]
    #print(Y)
    ye.append(Y)

print(ye)
# Out:
# [53.294923534063734, -53.59194657519257, 15.356399746313652, -44.14429614743936, -36.084697006060566, 36.343578910120485, -7.184611887588343, 48.77200724669804, 41.50820296484809, 7.298973551805288, 63.753686355510425, -45.70549378558226, 27.442033626451583, -1.5432381310696552, -4.793254757325048, 46.3904094920302, 5.927964101696024, 5.822815158318992, -40.46342507778142, 69.64297615852975]

# %% [markdown]
# ## Guardando a un .txt

# %% [markdown]
# Ahora, quiero guardar estos datos en un archivo de texto. Quizás en la versión final para la web no haga falta, pero ahora es útil.
#
# Un sitio donde está bien explicado cómo crear y controlar archivos de texto desde python es https://www.guru99.com/reading-and-writing-files-in-python.html

# %%
file = open("example.txt","w+")

for i in range(t):
    file.write(str(i+1)+","+str(ye[i])+"\n")

file.close()

# %% [markdown]
# Quiero poder ver el archivo de texto creado en el propio notebook.
# Para eso, he sacado el siguiente código de https://stackoverflow.com/questions/13957025/how-to-upload-a-text-file-into-ipython-notebook

# %%
text_file = open("example.txt")
file_content = text_file.read()
print(file_content)
text_file.close()
# Out:
# 1,53.294923534063734
# 2,-53.59194657519257
# 3,15.356399746313652
# 4,-44.14429614743936
# 5,-36.084697006060566
# 6,36.343578910120485
# 7,-7.184611887588343
# 8,48.77200724669804
# 9,41.50820296484809
# 10,7.298973551805288
# 11,63.753686355510425
# 12,-45.70549378558226
# 13,27.442033626451583
# 14,-1.5432381310696552
# 15,-4.793254757325048
# 16,46.3904094920302
# 17,5.927964101696024
# 18,5.822815158318992
# 19,-40.46342507778142
# 20,69.64297615852975

# %% [markdown]
# ## Animando la generación de números

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style

style.use('fivethirtyeight')

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

def animate(i):
    graph_data = open('example.txt','r').read()
    lines = graph_data.split('\n')
    xs = []
    ys = []
    for line in lines:
        if len(line) > 1:
            x, y = line.split(',')
            xs.append(float(x))
            ys.append(float(y))
    ax1.clear()
    ax1.plot(xs, ys)

ani = animation.FuncAnimation(fig, animate, interval=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
file = open("example.txt","a")
file.write(str(22)+","+str(20)+"\n")
file.close()

text_file = open("example.txt")
file_content = text_file.read()
print(file_content)
text_file.close()
# Out:
# 1,53.294923534063734
# 2,-53.59194657519257
# 3,15.356399746313652
# 4,-44.14429614743936
# 5,-36.084697006060566
# 6,36.343578910120485
# 7,-7.184611887588343
# 8,48.77200724669804
# 9,41.50820296484809
# 10,7.298973551805288
# 11,63.753686355510425
# 12,-45.70549378558226
# 13,27.442033626451583
# 14,-1.5432381310696552
# 15,-4.793254757325048
# 16,46.3904094920302
# 17,5.927964101696024
# 18,5.822815158318992
# 19,-40.46342507778142
# 20,69.64297615852975
# 22,20
# 22,20

# %% [markdown]
# def animate(i):
#     xs = []
#     ys = []
#     for k in range(t):
#         xs.append(k)
#         ys.append(ye[k])
#     ax1.clear()
#     ax1.plot(xs, ys)
